# %%
# %matplotlib notebook

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
#Read in real estate data csv file
csvfile = 'RDC_InventoryCoreMetrics_Zip_Hist.csv'
csvfile2 = 'allsurveyedited-edit.csv'

# %%
survey_df = pd.read_csv(csvfile2)
survey_df.head()
# Out:
#    Zip Code   Mall            numstores shopping_style apparel Shoes  \
# 0     60062  north  Two or Three Stores          Deals       1
# 1     60062  north  Two or Three Stores            Fun       1     1
# 2     60062  north  Two or Three Stores         Trends       1     1
# 3     60062  north  Two or Three Stores          Deals       1
# 4     60062  north  Two or Three Stores          Deals       1     1
#
#   Accessories Jewelry ToysGames Books      ...      with_family With_friends  \
# 0                                          ...
# 1           1                 1            ...                1
# 2           1                              ...
# 3           1                              ...
# 4           1                              ...                1            1
#
#   Myself For_family For_friends depends  gender    age       income  \
# 0      1                                   Male  45-54  100K - 149K
# 1                                     1          35-44       > 200K
# 2      1                                 Female  35-44       > 200K
# 3      1          1                              35-44       > 200K
# 4      1                              1          55-64       > 200K
#
#     family_type
# 0  married kids
# 1  married kids
# 2  married kids
# 3  married kids
# 4  married kids
#
# [5 rows x 38 columns]

# %%
survey_df_demo = survey_df[["Zip Code", "Mall", "gender", "age", "income", "family_type"]]
survey_df_demo.head()
# Out:
#    Zip Code   Mall  gender    age       income   family_type
# 0     60062  north    Male  45-54  100K - 149K  married kids
# 1     60062  north          35-44       > 200K  married kids
# 2     60062  north  Female  35-44       > 200K  married kids
# 3     60062  north          35-44       > 200K  married kids
# 4     60062  north          55-64       > 200K  married kids

# %%
north = survey_df.loc[survey_df["Mall"] == "north", :]
water = survey_df.loc[survey_df["Mall"] == "water", :]
oak = survey_df.loc[survey_df["Mall"] == "oak", :]
spring = survey_df.loc[survey_df["Mall"] == "spring", :]

north_ages = pd.unique(north["age"])
north_ages
# Out:
# array(['45-54', '35-44', '55-64', '75 +', '65-74', '18-25', '26-34', ' ',
#        '13-17'], dtype=object)

# %%
north_1317 = north.loc[(north["age"] == "13-17")]
#len(north_1317["age"])
north_1825 = north.loc[(north["age"] == "18-25")]
north_2634 = north.loc[(north["age"] == "26-34")]
north_3544 = north.loc[(north["age"] == "35-44")]
north_4554 = north.loc[(north["age"] == "45-54")]
north_5564 = north.loc[(north["age"] == "55-64")]
north_6574 = north.loc[(north["age"] == "65-74")]
north_75plus = north.loc[(north["age"] == "75 +")]
north_undef = north.loc[(north["age"] == " ")]


north_ages = [len(north_1317["age"]), len(north_1825["age"]), len(north_2634["age"]), 
              len(north_3544["age"]), len(north_4554["age"]), len(north_5564["age"]), 
              len(north_6574["age"]), len(north_75plus["age"]), len(north_undef["age"])]

north_ages
# Out:
# [12, 44, 72, 126, 151, 129, 45, 30, 16]

# %%
# Create a bar chart based upon the above data

ages = ["13-17", "18-25", "26-34", "35-44", "45-54", "55-64", "65-74", "75 +", "blanks"]
x_axis = np.arange(len(ages))

plt.bar(ages, north_ages, color="b", align="center")

plt.title("Age Distribution - Northbrook")
plt.xlabel("Ages")
plt.ylabel("# of Visitors")

plt.show()

#plt.legend(handles=[water_tower, northbrook, oak_brook, dundee], loc="best")
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
# Using GroupBy in order to separate the data into fields according to "state" values
#df_bymall = survey_df.groupby(['Mall'])

# The object returned is a "GroupBy" object and cannot be viewed normally...
#print(grouped_usa_df)

# In order to be visualized, a data function must be used...
#df_bymall.head(10)
# Out:
#       Zip Code    Mall             numstores shopping_style apparel Shoes  \
# 0        60062   north   Two or Three Stores          Deals       1
# 1        60062   north   Two or Three Stores            Fun       1     1
# 2        60062   north   Two or Three Stores         Trends       1     1
# 3        60062   north   Two or Three Stores          Deals       1
# 4        60062   north   Two or Three Stores          Deals       1     1
# 5        60062   north  Four Stores and More          Deals       1     1
# 6        60062   north   Two or Three Stores           Know       1
# 7        60062   north   Two or Three Stores          Deals       1
# 8        60062   north   Two or Three Stores            Fun       1
# 9        60062   north   Two or Three Stores           Know       1
# 625      60503     oak  Four Stores and More         Trends       1
# 626      60503     oak  Four Stores and More         Trends       1
# 627      60503     oak  Four Stores and More         Trends       1     1
# 628      60503     oak   Two or Three Stores         Trends       1
# 629      60503     oak  Four Stores and More          Deals       1
# 630      60503     oak  Four Stores and More         Trends       1     1
# 631      60503     oak  Four Stores and More            Fun       1
# 632      60503     oak   Two or Three Stores          Deals       1     1
# 633      60503     oak  Four Stores and More          Deals       1     1
# 634      60503     oak  Four Stores and More          Deals       1     1
# 1850     60611   water  Four Stores and More            Fun       1
# 1851     60611   water  Four Stores and More         Trends       1     1
# 1852     60611   water  Four Stores and More            Fun       1
# 1853     60611   water  Four Stores and More          Deals       1
# 1854     60611   water  Four Stores and More            Fun       1     1
# 1855     60611   water  Four Stores and More         Trends       1
# 1856     60611   water   Two or Three Stores          Deals       1     1
# 1857     60611   water   Two or Three Stores         Trends       1     1
# 1858     60611   water  Four Stores and More            Fun       1     1
# 1859     60611   water  Four Stores and More         Trends       1     1
# 2406     60118  spring  Four Stores and More            Fun       1
# 2407     60118  spring  Four Stores and More         Trends       1
# 2408     60118  spring  Four Stores and More          Deals       1     1
# 2409     60118  spring  Four Stores and More          Deals       1     1
# 2410     60118  spring  Four Stores and More          Deals       1     1
# 2411     60118  spring  Four Stores and More          Deals       1     1
# 2412     60118  spring   Two or Three Stores           Know
# 2413     60118  spring  Four Stores and More          Deals       1
# 2414     60118  spring             One Store           Know       1
# 2415     60118  spring  Four Stores and More          Deals       1     1
#
#      Accessories Jewelry ToysGames Books       ...        with_family  \
# 0                                              ...
# 1              1                 1             ...                  1
# 2              1                               ...
# 3              1                               ...
# 4              1                               ...                  1
# 5                      1                       ...
# 6              1                               ...
# 7              1                               ...
# 8                                              ...
# 9                                              ...
# 625                              1     1       ...                  1
# 626                                    1       ...
# 627            1                               ...                  1
# 628            1                               ...                  1
# 629                    1                       ...                  1
# 630            1                       1       ...                  1
# 631            1                               ...                  1
# 632                                    1       ...
# 633            1       1                       ...                  1
# 634            1       1                       ...
# 1850                                           ...
# 1851           1                               ...
# 1852                                           ...
# 1853                                           ...                  1
# 1854           1       1                       ...
# 1855                                           ...
# 1856           1                               ...
# 1857           1                               ...
# 1858           1       1                       ...
# 1859                                           ...                  1
# 2406           1                 1     1       ...
# 2407                             1     1       ...                  1
# 2408                                           ...
# 2409           1       1               1       ...                  1
# 2410           1       1                       ...                  1
# 2411           1       1                       ...
# 2412           1                               ...
# 2413                                   1       ...                  1
# 2414                                           ...
# 2415           1                               ...                  1
#
#      With_friends Myself For_family For_friends depends  gender    age  \
# 0                      1                                   Male  45-54
# 1                                                     1          35-44
# 2                      1                                 Female  35-44
# 3                      1          1                              35-44
# 4               1      1                              1          55-64
# 5                      1                                 Female  55-64
# 6                      1                                 Female  45-54
# 7                                                     1  Female  45-54
# 8                                 1                      Female  45-54
# 9                                                     1    Male  55-64
# 625             1      1                              1  Female  35-44
# 626                                                   1  Female  55-64
# 627             1      1                                 Female  18-25
# 628                    1          1                        Male  18-25
# 629             1      1          1                      Female  18-25
# 630             1      1                              1  Female  13-17
# 631                    1          1                      Female  35-44
# 632                                                   1  Female  35-44
# 633             1      1                              1  Female  18-25
# 634                                                   1  Female  55-64
# 1850            1      1                                 Female  18-25
# 1851            1      1                                 Female  18-25
# 1852                   1                                 Female  26-34
# 1853                                                  1          26-34
# 1854            1      1                              1  Female  26-34
# 1855                   1                                 Female  26-34
# 1856                   1                                 Female  18-25
# 1857            1                                     1  Female  26-34
# 1858            1                                     1  Female  26-34
# 1859            1      1          1                      Female  18-25
# 2406            1      1                              1  Female  18-25
# 2407                              1                        Male  26-34
# 2408            1      1                                 Female  26-34
# 2409                   1          1                   1  Female  45-54
# 2410            1      1                                 Female  18-25
# 2411            1      1          1           1       1  Female  26-34
# 2412                              1                      Female  65-74
# 2413            1                                     1  Female  18-25
# 2414                   1                                   Male  65-74
# 2415                   1          1                      Female  35-44
#
#            income      family_type
# 0     100K - 149K     married kids
# 1          > 200K     married kids
# 2          > 200K     married kids
# 3          > 200K     married kids
# 4          > 200K     married kids
# 5       30K - 59K     married kids
# 6         60K-99K     married kids
# 7          > 200K     married kids
# 8         60K-99K  married no kids
# 9          > 200K     married kids
# 625     30K - 59K     married kids
# 626   100K - 149K     married kids
# 627       60K-99K   single no kids
# 628        > 200K     married kids
# 629     30K - 59K     married kids
# 630         < 30K   single no kids
# 631        > 200K     married kids
# 632   100K - 149K     married kids
# 633         < 30K   single no kids
# 634     30K - 59K      single kids
# 1850        < 30K   single no kids
# 1851        < 30K   single no kids
# 1852      60K-99K  married no kids
# 1853      60K-99K   single no kids
# 1854  100K - 149K  married no kids
# 1855    30K - 59K   single no kids
# 1856        < 30K   single no kids
# 1857      60K-99K   single no kids
# 1858        < 30K   single no kids
# 1859        < 30K   single no kids
# 2406  100K - 149K   single no kids
# 2407      60K-99K      single kids
# 2408        < 30K   single no kids
# 2409    30K - 59K      single kids
# 2410        < 30K   single no kids
# 2411  100K - 149K  married no kids
# 2412        < 30K      single kids
# 2413        < 30K      single kids
# 2414      60K-99K     married kids
# 2415    30K - 59K     married kids
#
# [40 rows x 38 columns]

# %%
re_df = pd.read_csv(csvfile)
re_df.head()
# Out:
#         Month  ZipCode          ZipName Footnote  Median Listing Price  \
# 0  2017-09-01   1001.0       Agawam, MA      NaN              213700.0
# 1  2017-09-01   1002.0      Amherst, MA      NaN              358500.0
# 2  2017-09-01   1005.0        Barre, MA      NaN              251300.0
# 3  2017-09-01   1007.0  Belchertown, MA      NaN              333600.0
# 4  2017-09-01   1008.0    Blandford, MA      NaN              186200.0
#
#    Median Listing Price M/M  Median Listing Price Y/Y  Active Listing Count   \
# 0                   -0.0387                   -0.0286                   52.0
# 1                   -0.0465                    0.0913                  110.0
# 2                   -0.0408                    0.1100                   24.0
# 3                   -0.0039                    0.1120                   82.0
# 4                    0.0081                   -0.0432                   14.0
#
#    Active Listing Count M/M  Active Listing Count Y/Y        ...          \
# 0                    0.0612                   -0.2571        ...
# 1                   -0.0678                   -0.0351        ...
# 2                    0.1429                   -0.1724        ...
# 3                   -0.0353                   -0.0889        ...
# 4                    0.0000                   -0.2222        ...
#
#    Pending Listing Count Y/Y  Avg Listing Price  Avg Listing Price M/M  \
# 0                        0.0           248200.0                -0.0028
# 1                        NaN           444400.0                 0.0018
# 2                        NaN           250900.0                -0.0260
# 3                        NaN           331500.0                -0.0140
# 4                        0.0           257300.0                 0.0235
#
#    Avg Listing Price Y/Y  Total Listing Count  Total Listing Count M/M  \
# 0                 0.0973                 53.0                   0.0600
# 1                 0.2396                110.0                  -0.0678
# 2                 0.0321                 24.0                   0.1429
# 3                 0.0805                 82.0                  -0.0353
# 4                -0.3675                 15.0                   0.0000
#
#    Total Listing Count Y/Y  Pending Ratio  Pending Ratio M/M  \
# 0                  -0.2535         0.0192            -0.0012
# 1                  -0.0351         0.0000             0.0000
# 2                  -0.1724         0.0000             0.0000
# 3                  -0.0889         0.0000             0.0000
# 4                  -0.2105         0.0714             0.0000
#
#    Pending Ratio Y/Y
# 0             0.0049
# 1             0.0000
# 2             0.0000
# 3             0.0000
# 4             0.0159
#
# [5 rows x 34 columns]

# %%
#Remove unnecessary columns

re_df_clean = re_df[["Month", "ZipCode", "ZipName", "Median Listing Price", "Active Listing Count ", "Days on Market ",]]
re_df_clean.head()
# Out:
#         Month  ZipCode          ZipName  Median Listing Price  \
# 0  2017-09-01   1001.0       Agawam, MA              213700.0
# 1  2017-09-01   1002.0      Amherst, MA              358500.0
# 2  2017-09-01   1005.0        Barre, MA              251300.0
# 3  2017-09-01   1007.0  Belchertown, MA              333600.0
# 4  2017-09-01   1008.0    Blandford, MA              186200.0
#
#    Active Listing Count   Days on Market
# 0                   52.0             50.0
# 1                  110.0             76.0
# 2                   24.0             72.0
# 3                   82.0             74.0
# 4                   14.0             86.0

# %%
#Break down 
df60611 = re_df_clean[re_df_clean["ZipCode"] == 60611.0]
df60611.head()
# Out:
#             Month  ZipCode      ZipName  Median Listing Price  \
# 10131  2017-09-01  60611.0  Chicago, IL              597000.0
# 25164  2017-08-01  60611.0  Chicago, IL              629000.0
# 40190  2017-07-01  60611.0  Chicago, IL              620000.0
# 55218  2017-06-01  60611.0  Chicago, IL              610900.0
# 70246  2017-05-01  60611.0  Chicago, IL              599000.0
#
#        Active Listing Count   Days on Market
# 10131                  770.0             62.0
# 25164                  739.0             62.0
# 40190                  761.0             61.0
# 55218                  775.0             56.0
# 70246                  751.0             60.0

# %%
df60062 = re_df_clean[re_df_clean["ZipCode"] == 60062.0]
df60062.head()
# Out:
#             Month  ZipCode         ZipName  Median Listing Price  \
# 9925   2017-09-01  60062.0  Northbrook, IL              547300.0
# 24958  2017-08-01  60062.0  Northbrook, IL              555000.0
# 39984  2017-07-01  60062.0  Northbrook, IL              579000.0
# 55012  2017-06-01  60062.0  Northbrook, IL              597700.0
# 70040  2017-05-01  60062.0  Northbrook, IL              599000.0
#
#        Active Listing Count   Days on Market
# 9925                   432.0             61.0
# 24958                  451.0             59.0
# 39984                  478.0             54.0
# 55012                  496.0             53.0
# 70040                  496.0             57.0

# %%
df60523 = re_df_clean[re_df_clean["ZipCode"] == 60523.0]
df60523.head()
# Out:
#             Month  ZipCode        ZipName  Median Listing Price  \
# 10095  2017-09-01  60523.0  Oak Brook, IL              870500.0
# 25128  2017-08-01  60523.0  Oak Brook, IL              856700.0
# 40154  2017-07-01  60523.0  Oak Brook, IL              849000.0
# 55182  2017-06-01  60523.0  Oak Brook, IL              799500.0
# 70210  2017-05-01  60523.0  Oak Brook, IL              849300.0
#
#        Active Listing Count   Days on Market
# 10095                  149.0             91.0
# 25128                  150.0             95.0
# 40154                  152.0             80.0
# 55182                  162.0             67.0
# 70210                  159.0             63.0

# %%
df60118 = re_df_clean[re_df_clean["ZipCode"] == 60118.0]
df60118.head()
# Out:
#             Month  ZipCode     ZipName  Median Listing Price  \
# 9959   2017-09-01  60118.0  Dundee, IL              290000.0
# 24992  2017-08-01  60118.0  Dundee, IL              299000.0
# 40018  2017-07-01  60118.0  Dundee, IL              299000.0
# 55046  2017-06-01  60118.0  Dundee, IL              300000.0
# 70074  2017-05-01  60118.0  Dundee, IL              294200.0
#
#        Active Listing Count   Days on Market
# 9959                   126.0             54.0
# 24992                  117.0             61.0
# 40018                  123.0             60.0
# 55046                  126.0             50.0
# 70074                  118.0             54.0

# %%
#Visualize real estate pricing trends for each zip code

months60611 = df60611["Month"]
price60611 = df60611["Median Listing Price"]

months60062 = df60062["Month"]
price60062 = df60062["Median Listing Price"]

months60523 = df60523["Month"]
price60523 = df60523["Median Listing Price"]

months60118 = df60118["Month"]
price60118 = df60118["Median Listing Price"]


water_tower, = plt.plot(months60611, price60611, color="red", label="60611")
northbrook, = plt.plot(months60062, price60062, color="blue", label="60062")
oak_brook, = plt.plot(months60523, price60523, color="green", label="60523")
dundee, = plt.plot(months60118, price60118, color="orange", label="60118")

plt.title("Median Home Prices in Target Zip Codes")
plt.xlabel("May 2012 - Sept 2017")
plt.ylabel("Median Home Price")

plt.legend(handles=[water_tower, northbrook, oak_brook, dundee], loc="best")
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
#IL_zip = re_df_clean[re_df_clean.ZipName.str.endswith('IL')]
#IL_zip.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-101-d66a12e260a4> in <module>
# ----> 1 IL_zip = re_df_clean[re_df_clean.ZipName.str.endswith('IL')]
#       2 IL_zip.head()
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2680         if isinstance(key, (Series, np.ndarray, Index, list)):
#    2681             # either boolean or fancy integer index
# -> 2682             return self._getitem_array(key)
#    2683         elif isinstance(key, DataFrame):
#    2684             return self._getitem_frame(key)
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\core\frame.py in _getitem_array(self, key)
#    2707     def _getitem_array(self, key):
#    2708         # also raises Exception if object array with NA values
# -> 2709         if com.is_bool_indexer(key):
#    2710             # warning here just in case -- previously __setitem__ was
#    2711             # reindexing but __getitem__ was not; it seems more reasonable to
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\core\common.py in is_bool_indexer(key)
#     105             if not lib.is_bool_array(key):
#     106                 if isna(key).any():
# --> 107                     raise ValueError('cannot index with vector containing '
#     108                                      'NA / NaN values')
#     109                 return False
#
# ValueError: cannot index with vector containing NA / NaN values
